# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt
plt.imshow(train_images[30190], cmap=plt.cm.binary)
plt.show()

# %%
train_labels[30190]
# Out:
# 7

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 6s 10ms/step - loss: 0.2534 - accuracy: 0.9278
# Epoch 2/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1021 - accuracy: 0.9699
# Epoch 3/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0674 - accuracy: 0.9801
# Epoch 4/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0487 - accuracy: 0.9854
# Epoch 5/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0365 - accuracy: 0.9888

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0679 - accuracy: 0.9790
# test_acc: 0.9789999723434448
